# %% [markdown]
# # End-to-end injection for Shopify (development) store

# %%
# Credentials

import os
from dotenv import load_dotenv

load_dotenv()

store_api_key = os.getenv("SHOPIFY_API_KEY")
store_secret_key = os.getenv("SHOPIFY_SECRET_KEY")
admin_api_access_token = os.getenv("SHOPIFY_ADMIN_API_ACCESS_TOKEN")

shop_url = "urban-thread-test-store.myshopify.com"
api_version = '2025-07'

# %%
import shopify
shopify.Session.setup(api_key=store_api_key, secret=store_secret_key)

session = shopify.Session(shop_url, api_version, admin_api_access_token)

# %%
shopify.ShopifyResource.activate_session(session)

# %% [markdown]
# # Inject customers data

# %%
import pandas as pd
import time

df_sorted = pd.read_csv('./data/shopify_customers_sorted.csv')
# df_sorted_first_five = df_sorted.head(5).copy()

# %%
# Iterate over each row in df_sorted_first_five, inject into Shopify, get the id, and add to a new "id" column

ids = []
for idx, row in df_sorted.iterrows():
    new_customer = shopify.Customer()
    # Split the full name into first and last name
    full_name = row.get("name", "")
    name_parts = full_name.strip().split(" ", 1)
    first_name = name_parts[0] if len(name_parts) > 0 else ""
    last_name = name_parts[1] if len(name_parts) > 1 else ""
    
    new_customer.first_name = first_name
    new_customer.last_name = last_name
    new_customer.email = row.get("email", "")
    # Add createdAt from created_at column

    new_customer.createdAt = row["created_at"]
    # Add any other fields as needed, e.g. phone, address, etc.
    
    new_customer.save()
    ids.append(new_customer.id)

    # Add a delay to avoid hitting Shopify API rate limits
    time.sleep(0.2)

df_sorted["id"] = [str(i) for i in ids]

# %%
display(df_sorted)
# Out:
#                    name                               email  gender  age  \
# 0      Christopher Bass    christopher.bass@dummydomain.com    male   58
# 1         Daniel Wagner       daniel.wagner@dummydomain.com    male   50
# 2         Stephen Mckee       stephen.mckee@dummydomain.com    male   30
# 3           Patty Perez         patty.perez@dummydomain.com  female   35
# 4        Dominic Jacobs      dominic.jacobs@dummydomain.com    male   40
# ..                  ...                                 ...     ...  ...
# 388  Stephanie Williams  stephanie.williams@dummydomain.com  female   64
# 389      Carolyn Miller      carolyn.miller@dummydomain.com  female   51
# 390       Shannon James       shannon.james@dummydomain.com  female   18
# 391       Briana Murray       briana.murray@dummydomain.com  female   65
# 392         David Smith         david.smith@dummydomain.com    male   47
#
#      created_at      segment             id
# 0    2024-01-01  prospective  9059439771976
# 1    2024-01-04    returning  9059439804744
# 2    2024-01-05      churned  9059439837512
# 3    2024-01-05      churned  9059439870280
# 4    2024-01-06  prospective  9059439935816
# ..          ...          ...            ...
# 388  2025-03-26  prospective  9059457007944
# 389  2025-03-26  prospective  9059457040712
# 390  2025-03-27  prospective  9059457139016
# 391  2025-03-27      churned  9059457171784
# 392  2025-03-28    returning  9059457237320
#
# [393 rows x 7 columns]

# %% [markdown]
# ## Save the customer df with unique ids to new csv

# %%
df_sorted.to_csv('./data/shopify_customers_sorted_with_id.csv', index=False)

# %% [markdown]
# # Inject products data

# %%
import numpy as np
import re

product_df = pd.read_csv('./data/shopify_products_cleaned.csv')


# Helper: Check if a value is NaN
def is_nan(x):
    return pd.isna(x) or (isinstance(x, float) and np.isnan(x))

# Helper: Extract numeric id from Shopify GID
def extract_numeric_id(gid):
    if not isinstance(gid, str):
        return ""
    match = re.search(r'/(\d+)$', gid)
    return match.group(1) if match else ""

# Add a new column for variant_id, initialized as empty string
product_df['variant_id'] = ""

# 1. Find the first two unique products
# unique_titles = product_df['title'].drop_duplicates().head(2).tolist()
unique_titles = product_df['title'].drop_duplicates().tolist()

for title in unique_titles:
    product_rows = product_df[product_df['title'] == title]

    # Use the first row for product-level fields
    first_row = product_rows.iloc[0]

    description = first_row['description']
    product_type = first_row['product_type']
    tags = first_row['tags']
    published_at = first_row['release_date']
    
    # 2. Find product options (Size, Color)
    option_names = []
    if 'variant_size' in product_rows.columns and product_rows['variant_size'].notna().any():
        option_names.append('Size')
    if 'variant_color' in product_rows.columns and product_rows['variant_color'].notna().any():
        option_names.append('Color')
    
    # Build productOptions
    product_options = []
    for idx, opt in enumerate(option_names):
        if opt == 'Size':
            values = sorted(product_rows['variant_size'].dropna().unique().tolist())
        elif opt == 'Color':
            values = sorted(product_rows['variant_color'].dropna().unique().tolist())
        else:
            values = []
        product_options.append({
            "name": opt,
            "position": idx + 1,
            "values": [{"name": v} for v in values]
        })
    
    # 3. Build variants
    variants = []
    variant_row_indices = []  # To keep track of the DataFrame indices for each variant
    for idx, row in product_rows.iterrows():
        option_values = []
        if 'Color' in option_names:
            option_values.append({"optionName": "Color", "name": row['variant_color']})
        if 'Size' in option_names:
            option_values.append({"optionName": "Size", "name": row['variant_size']})
        # Inventory policy and quantity
        discontinued = not is_nan(row.get('discontinued_date', np.nan))
        quantity = 0 if discontinued else int(row['inventory_quantity'])
        variant = {
            "optionValues": option_values,
            "price": float(row['price']),
            "inventoryPolicy": "CONTINUE",
            # "inventoryQuantities": [
            #     {
            #         "quantity": quantity,
            #         # "locationId": None  # If you have a locationId, set it here
            #     }
            # ]
        }
        variants.append(variant)
        variant_row_indices.append(idx)
    
    # 4. Build the productSet input
    product_input = {
        "title": title,
        "descriptionHtml": description,
        "productType": product_type,
        "tags": tags,
        # "publishedAt": published_at,
        "productOptions": product_options,
        "variants": variants
    }
    
    # 5. Prepare mutation and variables
    mutation = """
        mutation createProductAsynchronous($productSet: ProductSetInput!, $synchronous: Boolean!) {
          productSet(synchronous: $synchronous, input: $productSet) {
            product {
              id
              variants(first: 100) {
                edges {
                  node {
                    id
                    title
                  }
                }
              }
            }
            productSetOperation {
              id
              status
              userErrors {
                code
                field
                message
              }
            }
            userErrors {
              code
              field
              message
            }
          }
        }
    """
    variables = {
        "synchronous": True,
        "productSet": product_input
    }
    
    # 6. Execute the mutation
    result = shopify.GraphQL().execute(mutation, variables=variables)
    print(f"Result for product '{title}':")
    print(result)
    # Extract and save variant IDs to the DataFrame
    try:
        import json
        if isinstance(result, str):
            data = json.loads(result)
        else:
            data = result
        variants_data = (
            data.get("data", {})
            .get("productSet", {})
            .get("product", {})
            .get("variants", {})
            .get("edges", [])
        )
        variant_ids = [edge["node"]["id"] for edge in variants_data]
        print("Variant IDs:", variant_ids)
        # Save only the numeric id to the corresponding rows in the DataFrame
        for idx, variant_id in zip(variant_row_indices, variant_ids):
            product_df.at[idx, 'variant_id'] = extract_numeric_id(variant_id)
    except Exception as e:
        print("Could not extract variant IDs:", e)
# Out:
# Result for product 'Classic Cotton Tee':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678642504","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944337215816","title":"XS / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944337248584","title":"S / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944337281352","title":"M / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944337314120","title":"L / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944337346888","title":"XL / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944337379656","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944337412424","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944337445192","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944337477960","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944337510728","title":"XL / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944337543496","title":"XS / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944337576264","title":"S / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944337609032","title":"M / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944337641800","title":"L / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944337674568","title":"XL / Navy"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":57,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1943,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944337215816', 'gid://shopify/ProductVariant/50944337248584', 'gid://shopify/ProductVariant/50944337281352', 'gid://shopify/ProductVariant/50944337314120', 'gid://shopify/ProductVariant/50944337346888', 'gid://shopify/ProductVariant/50944337379656', 'gid://shopify/ProductVariant/50944337412424', 'gid://shopify/ProductVariant/50944337445192', 'gid://shopify/ProductVariant/50944337477960', 'gid://shopify/ProductVariant/50944337510728', 'gid://shopify/ProductVariant/50944337543496', 'gid://shopify/ProductVariant/50944337576264', 'gid://shopify/ProductVariant/50944337609032', 'gid://shopify/ProductVariant/50944337641800', 'gid://shopify/ProductVariant/50944337674568']
# Result for product 'Slim Fit Crew Tee':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678675272","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944337936712","title":"XS / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944337969480","title":"S / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944338002248","title":"M / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944338035016","title":"L / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944338067784","title":"XL / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944338100552","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338133320","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338166088","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338198856","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338231624","title":"XL / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338264392","title":"XS / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944338297160","title":"S / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944338329928","title":"M / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944338362696","title":"L / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944338395464","title":"XL / Grey"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":57,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1941,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944337936712', 'gid://shopify/ProductVariant/50944337969480', 'gid://shopify/ProductVariant/50944338002248', 'gid://shopify/ProductVariant/50944338035016', 'gid://shopify/ProductVariant/50944338067784', 'gid://shopify/ProductVariant/50944338100552', 'gid://shopify/ProductVariant/50944338133320', 'gid://shopify/ProductVariant/50944338166088', 'gid://shopify/ProductVariant/50944338198856', 'gid://shopify/ProductVariant/50944338231624', 'gid://shopify/ProductVariant/50944338264392', 'gid://shopify/ProductVariant/50944338297160', 'gid://shopify/ProductVariant/50944338329928', 'gid://shopify/ProductVariant/50944338362696', 'gid://shopify/ProductVariant/50944338395464']
# Result for product 'Heavyweight Oversized Tee':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678708040","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944338526536","title":"XS / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944338559304","title":"S / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944338592072","title":"M / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944338624840","title":"L / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944338657608","title":"XL / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944338690376","title":"XS / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944338723144","title":"S / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944338755912","title":"M / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944338788680","title":"L / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944338821448","title":"XL / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944338854216","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338886984","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338919752","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338952520","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944338985288","title":"XL / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":57,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1932,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944338526536', 'gid://shopify/ProductVariant/50944338559304', 'gid://shopify/ProductVariant/50944338592072', 'gid://shopify/ProductVariant/50944338624840', 'gid://shopify/ProductVariant/50944338657608', 'gid://shopify/ProductVariant/50944338690376', 'gid://shopify/ProductVariant/50944338723144', 'gid://shopify/ProductVariant/50944338755912', 'gid://shopify/ProductVariant/50944338788680', 'gid://shopify/ProductVariant/50944338821448', 'gid://shopify/ProductVariant/50944338854216', 'gid://shopify/ProductVariant/50944338886984', 'gid://shopify/ProductVariant/50944338919752', 'gid://shopify/ProductVariant/50944338952520', 'gid://shopify/ProductVariant/50944338985288']
# Result for product 'Oversized Pullover Hoodie':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678740808","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944339280200","title":"XS / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944339312968","title":"S / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944339345736","title":"M / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944339378504","title":"L / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944339411272","title":"XL / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944339444040","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944339476808","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944339509576","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944339542344","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944339575112","title":"XL / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944339607880","title":"XS / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944339640648","title":"S / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944339673416","title":"M / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944339706184","title":"L / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944339738952","title":"XL / Navy"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":57,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1943,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944339280200', 'gid://shopify/ProductVariant/50944339312968', 'gid://shopify/ProductVariant/50944339345736', 'gid://shopify/ProductVariant/50944339378504', 'gid://shopify/ProductVariant/50944339411272', 'gid://shopify/ProductVariant/50944339444040', 'gid://shopify/ProductVariant/50944339476808', 'gid://shopify/ProductVariant/50944339509576', 'gid://shopify/ProductVariant/50944339542344', 'gid://shopify/ProductVariant/50944339575112', 'gid://shopify/ProductVariant/50944339607880', 'gid://shopify/ProductVariant/50944339640648', 'gid://shopify/ProductVariant/50944339673416', 'gid://shopify/ProductVariant/50944339706184', 'gid://shopify/ProductVariant/50944339738952']
# Result for product 'Denim Jacket':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678773576","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944339968328","title":"XS / Washed Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944340001096","title":"S / Washed Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944340033864","title":"M / Washed Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944340066632","title":"L / Washed Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944340099400","title":"XL / Washed Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1945,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944339968328', 'gid://shopify/ProductVariant/50944340001096', 'gid://shopify/ProductVariant/50944340033864', 'gid://shopify/ProductVariant/50944340066632', 'gid://shopify/ProductVariant/50944340099400']
# Result for product 'Relaxed Fit Chinos':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678806344","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944340296008","title":"XS / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944340328776","title":"S / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944340361544","title":"M / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944340394312","title":"L / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944340427080","title":"XL / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944340459848","title":"XS / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944340492616","title":"S / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944340525384","title":"M / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944340558152","title":"L / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944340590920","title":"XL / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944340623688","title":"XS / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944340656456","title":"S / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944340689224","title":"M / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944340721992","title":"L / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944340754760","title":"XL / Beige"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":57,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1935,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944340296008', 'gid://shopify/ProductVariant/50944340328776', 'gid://shopify/ProductVariant/50944340361544', 'gid://shopify/ProductVariant/50944340394312', 'gid://shopify/ProductVariant/50944340427080', 'gid://shopify/ProductVariant/50944340459848', 'gid://shopify/ProductVariant/50944340492616', 'gid://shopify/ProductVariant/50944340525384', 'gid://shopify/ProductVariant/50944340558152', 'gid://shopify/ProductVariant/50944340590920', 'gid://shopify/ProductVariant/50944340623688', 'gid://shopify/ProductVariant/50944340656456', 'gid://shopify/ProductVariant/50944340689224', 'gid://shopify/ProductVariant/50944340721992', 'gid://shopify/ProductVariant/50944340754760']
# Result for product 'Canvas Tote Bag':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678839112","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944340951368","title":"One Size / Natural"}},{"node":{"id":"gid://shopify/ProductVariant/50944340984136","title":"One Size / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944341016904","title":"One Size / Olive"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":54,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1932,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944340951368', 'gid://shopify/ProductVariant/50944340984136', 'gid://shopify/ProductVariant/50944341016904']
# Result for product 'Ankle Socks 3-Pack':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678871880","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944341246280","title":"One Size / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944341279048","title":"One Size / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944341311816","title":"One Size / Grey"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":54,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1925,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944341246280', 'gid://shopify/ProductVariant/50944341279048', 'gid://shopify/ProductVariant/50944341311816']
# Result for product 'Wool Beanie':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678904648","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944341442888","title":"One Size / Grey"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1917,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944341442888']
# Result for product 'Vintage Washed Tee':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678937416","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944341705032","title":"XS / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944341737800","title":"S / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944341770568","title":"M / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944341803336","title":"L / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944341836104","title":"XL / Blue"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1927,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944341705032', 'gid://shopify/ProductVariant/50944341737800', 'gid://shopify/ProductVariant/50944341770568', 'gid://shopify/ProductVariant/50944341803336', 'gid://shopify/ProductVariant/50944341836104']
# Result for product 'Mini Sling Bag':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587678970184","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944342098248","title":"One Size / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1922,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944342098248']
# Result for product 'Unisex Thermal Long Sleeve Tee':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679035720","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944342327624","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342360392","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342393160","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342425928","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342458696","title":"XL / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1923,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944342327624', 'gid://shopify/ProductVariant/50944342360392', 'gid://shopify/ProductVariant/50944342393160', 'gid://shopify/ProductVariant/50944342425928', 'gid://shopify/ProductVariant/50944342458696']
# Result for product 'Graphic Print Tee':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679068488","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944342688072","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342720840","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342753608","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342786376","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944342819144","title":"XL / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1929,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944342688072', 'gid://shopify/ProductVariant/50944342720840', 'gid://shopify/ProductVariant/50944342753608', 'gid://shopify/ProductVariant/50944342786376', 'gid://shopify/ProductVariant/50944342819144']
# Result for product 'Boxy Hoodie':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679101256","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944342982984","title":"XS / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343015752","title":"S / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343048520","title":"M / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343081288","title":"L / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343114056","title":"XL / Olive"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1923,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944342982984', 'gid://shopify/ProductVariant/50944343015752', 'gid://shopify/ProductVariant/50944343048520', 'gid://shopify/ProductVariant/50944343081288', 'gid://shopify/ProductVariant/50944343114056']
# Result for product 'Wide Leg Utility Pants':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679134024","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944343310664","title":"XS / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343343432","title":"S / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343376200","title":"M / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343408968","title":"L / Olive"}},{"node":{"id":"gid://shopify/ProductVariant/50944343441736","title":"XL / Olive"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1919,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944343310664', 'gid://shopify/ProductVariant/50944343343432', 'gid://shopify/ProductVariant/50944343376200', 'gid://shopify/ProductVariant/50944343408968', 'gid://shopify/ProductVariant/50944343441736']
# Result for product 'Minimalist Crewneck Sweatshirt':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679166792","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944343671112","title":"XS / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944343703880","title":"S / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944343736648","title":"M / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944343769416","title":"L / Grey"}},{"node":{"id":"gid://shopify/ProductVariant/50944343802184","title":"XL / Grey"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1916,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944343671112', 'gid://shopify/ProductVariant/50944343703880', 'gid://shopify/ProductVariant/50944343736648', 'gid://shopify/ProductVariant/50944343769416', 'gid://shopify/ProductVariant/50944343802184']
# Result for product 'Coach Jacket':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679199560","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944344031560","title":"XS / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944344064328","title":"S / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944344097096","title":"M / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944344129864","title":"L / Blue"}},{"node":{"id":"gid://shopify/ProductVariant/50944344162632","title":"XL / Blue"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1914,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944344031560', 'gid://shopify/ProductVariant/50944344064328', 'gid://shopify/ProductVariant/50944344097096', 'gid://shopify/ProductVariant/50944344129864', 'gid://shopify/ProductVariant/50944344162632']
# Result for product 'Relaxed Fit Cargo Shorts':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679232328","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944344326472","title":"XS / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944344359240","title":"S / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944344392008","title":"M / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944344424776","title":"L / Khaki"}},{"node":{"id":"gid://shopify/ProductVariant/50944344457544","title":"XL / Khaki"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1905,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944344326472', 'gid://shopify/ProductVariant/50944344359240', 'gid://shopify/ProductVariant/50944344392008', 'gid://shopify/ProductVariant/50944344424776', 'gid://shopify/ProductVariant/50944344457544']
# Result for product 'Loose Fit Tank Top':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679265096","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944344654152","title":"XS / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944344686920","title":"S / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944344719688","title":"M / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944344752456","title":"L / White"}},{"node":{"id":"gid://shopify/ProductVariant/50944344785224","title":"XL / White"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1900,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944344654152', 'gid://shopify/ProductVariant/50944344686920', 'gid://shopify/ProductVariant/50944344719688', 'gid://shopify/ProductVariant/50944344752456', 'gid://shopify/ProductVariant/50944344785224']
# Result for product '5-Panel Street Cap':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679330632","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944344981832","title":"One Size / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1900,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944344981832']
# Result for product 'Zip-Up Hoodie':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679363400","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944345276744","title":"XS / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944345309512","title":"S / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944345342280","title":"M / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944345375048","title":"L / Navy"}},{"node":{"id":"gid://shopify/ProductVariant/50944345407816","title":"XL / Navy"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1904,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944345276744', 'gid://shopify/ProductVariant/50944345309512', 'gid://shopify/ProductVariant/50944345342280', 'gid://shopify/ProductVariant/50944345375048', 'gid://shopify/ProductVariant/50944345407816']
# Result for product 'Slim Tapered Joggers':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679396168","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944345571656","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944345604424","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944345637192","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944345669960","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944345702728","title":"XL / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1907,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944345571656', 'gid://shopify/ProductVariant/50944345604424', 'gid://shopify/ProductVariant/50944345637192', 'gid://shopify/ProductVariant/50944345669960', 'gid://shopify/ProductVariant/50944345702728']
# Result for product 'Corduroy Bucket Hat':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679428936","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944345866568","title":"One Size / Brown"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1901,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944345866568']
# Result for product 'Ribbed Crew Socks':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679461704","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944346128712","title":"One Size / Grey"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1925,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944346128712']
# Result for product 'Quilted Bomber Jacket':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679494472","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944346292552","title":"XS / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944346325320","title":"S / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944346358088","title":"M / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944346390856","title":"L / Black"}},{"node":{"id":"gid://shopify/ProductVariant/50944346423624","title":"XL / Black"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1922,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944346292552', 'gid://shopify/ProductVariant/50944346325320', 'gid://shopify/ProductVariant/50944346358088', 'gid://shopify/ProductVariant/50944346390856', 'gid://shopify/ProductVariant/50944346423624']
# Result for product 'Streetwear Messenger Bag':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679527240","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944346620232","title":"One Size / Grey"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1931,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944346620232']
# Result for product 'Patterned Dress Socks':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679560008","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944346816840","title":"One Size / Navy"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":53,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1923,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944346816840']
# Result for product 'Thermal Hoodie':
# {"data":{"productSet":{"product":{"id":"gid://shopify/Product/9587679625544","variants":{"edges":[{"node":{"id":"gid://shopify/ProductVariant/50944347013448","title":"XS / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944347046216","title":"S / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944347078984","title":"M / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944347111752","title":"L / Beige"}},{"node":{"id":"gid://shopify/ProductVariant/50944347144520","title":"XL / Beige"}}]}},"productSetOperation":null,"userErrors":[]}},"extensions":{"cost":{"requestedQueryCost":62,"actualQueryCost":55,"throttleStatus":{"maximumAvailable":2000.0,"currentlyAvailable":1917,"restoreRate":100.0}}}}
# Variant IDs: ['gid://shopify/ProductVariant/50944347013448', 'gid://shopify/ProductVariant/50944347046216', 'gid://shopify/ProductVariant/50944347078984', 'gid://shopify/ProductVariant/50944347111752', 'gid://shopify/ProductVariant/50944347144520']

# %%
# Save the updated DataFrame to a new CSV file
product_df.to_csv('./data/shopify_products_cleaned_with_variant_ids.csv', index=False)

# %% [markdown]
# # Inject orders

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

import os
import json

load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
def open_customer_df(customer_csv_path):

    df = pd.read_csv(customer_csv_path)

    df['id'] = df['id'].apply(lambda x: str(int(float(x))) if pd.notnull(x) else '')

    # Add "last_buy_month" column: for now, set to the month of "created_at"
    created_at = pd.to_datetime(df['created_at'])
    df['last_buy_month'] = created_at.dt.strftime('%Y-%m')
    # Add "churn_date" column: for "churned" segment, set to created_at + X days, else NaT
    df['churn_date'] = pd.NaT
    mask_churned = df['segment'] == 'churned'
    import numpy as np
    # Add randomness: churned customers churn 20-40 days after created_at
    random_days = np.random.randint(20, 41, size=mask_churned.sum())
    df.loc[mask_churned, 'churn_date'] = pd.to_datetime(df.loc[mask_churned, 'created_at']) + pd.to_timedelta(random_days, unit='D')

    # For one-timer segment, churn_date is the first day of the next month after created_at
    mask_one_timer = df['segment'] == 'one-timer'
    created_at_one_timer = pd.to_datetime(df.loc[mask_one_timer, 'created_at'])
    # Set churn_date to next day after created_at
    churn_date_one_timer = (created_at_one_timer + pd.Timedelta(days=1)).dt.normalize()
    df.loc[mask_one_timer, 'churn_date'] = churn_date_one_timer

    return df

# %%
def open_product_df(product_csv_path):
    df = pd.read_csv(product_csv_path)

    # Convert 'variant_id' column to string type
    if 'variant_id' in df.columns:
        df['variant_id'] = df['variant_id'].apply(lambda x: str(int(float(x))) if pd.notnull(x) else '')
    
    return df

# %%
customer_df = open_customer_df('./data/shopify_customers_sorted_with_id.csv')
product_df = open_product_df('./data/shopify_products_cleaned_with_variant_ids.csv')


months = ['2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12', 
          '2025-01', '2025-02', '2025-03']

def get_valid_customers_for_month(customer_df, month):
    # Filter customers by created_at date
    customer_df['created_at'] = pd.to_datetime(customer_df['created_at'])
    # Ensure churn_date is datetime
    if 'churn_date' in customer_df.columns:
        customer_df['churn_date'] = pd.to_datetime(customer_df['churn_date'], errors='coerce')
    # Customers created before or in the given month
    month_end = pd.to_datetime(f"{month}-01") + pd.offsets.MonthEnd(0)
    valid_customers = customer_df[customer_df['created_at'] <= month_end].copy()

    # Further filter: churn_date must be in the future or NaT (not churned yet)
    if 'churn_date' in valid_customers.columns:
        # For the filter, use the first day of the month as the reference
        month_start = pd.to_datetime(f"{month}-01")
        valid_customers = valid_customers[(valid_customers['churn_date'].isna()) | (valid_customers['churn_date'] > month_start)]
    return valid_customers

def get_valid_products_for_month(product_df, month):
    # Filter products by release_date (should be any date before or in the current month)
    product_df['release_date'] = pd.to_datetime(product_df['release_date'])
    if 'discontinued_date' in product_df.columns:
        product_df['discontinued_date'] = pd.to_datetime(product_df['discontinued_date'], errors='coerce')

    # Get the first day of the current month and the last day of the current month
    month_start = pd.to_datetime(f"{month}-01")
    month_end = month_start + pd.offsets.MonthEnd(0)
    # Keep products released any time before or in the current month
    mask_created = (product_df['release_date'] <= month_end)

    filtered_df = product_df[mask_created].copy()

    # Filter out products discontinued before the start of this month
    if 'discontinued_date' in filtered_df.columns:
        filtered_df = filtered_df[(filtered_df['discontinued_date'].isna()) | (filtered_df['discontinued_date'] >= month_start)]

    return filtered_df

previous_month_prod_str = ''

all_months_prod_list = []

for i, month in enumerate(months):

    valid_cust = get_valid_customers_for_month(customer_df, month)
    valid_prod = get_valid_products_for_month(product_df, month)

    total_item_sold_in_month = int(round(1.5 * len(valid_cust)))

    valid_unique_prod = valid_prod['title'].drop_duplicates()

    valid_unique_prod_str = ', '.join(valid_unique_prod.tolist())

    llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2, api_key=openai_api_key)

    prompt = f"""
    You are a helpful assistant that generates order items for a Shopify store.
    You will be given a list of unique product titles for a given month.
    You need to assign a number of items sold for each product title.
    The total number of items sold should be equal to the total item sold in the month.

    You must assign the number to simulate a realistic distribution of items sold, mainly to simulate seasonality and new item releases.

    The current month is: {month}

    The list of unique product titles is:
    {valid_unique_prod_str}

    The total number of items sold in the month is:
    {total_item_sold_in_month}

    For info on what might be new products this month, you can use the following info of previous month products:
    {previous_month_prod_str}

    You must assign the number of items sold for each product title FOR THE CURRENT MONTH.
    You must assign the number of items sold for each product title FOR THE CURRENT MONTH.
    You must assign the number of items sold for each product title FOR THE CURRENT MONTH.

    You must return the result in the following JSON format:
    {{
      "thought": "Your reasoning about the distribution and any assumptions.",
      "product_list": [
        {{
          "product_title": "Product Title 1",
          "quantity_sold": <integer>
        }},
        {{
          "product_title": "Product Title 2",
          "quantity_sold": <integer>
        }}
        // ... one entry per product title
      ]
    }}

    Your answer:
    """

    response = llm.invoke(prompt)

    response_json = json.loads(response.content)

    
    all_months_prod_list.append({
        "month": month,
        "product_list": response_json['product_list']
    })

    previous_month_prod_str = valid_unique_prod_str

# %%
print(all_months_prod_list)
import json
import os

# Ensure the 'data' directory exists
os.makedirs('data', exist_ok=True)

with open('data/all_months_prod_list.json', 'w') as f:
    json.dump(all_months_prod_list, f, indent=2)
# Out:
# [{'month': '2024-01', 'product_list': [{'product_title': 'Classic Cotton Tee', 'quantity_sold': 5}, {'product_title': 'Slim Fit Crew Tee', 'quantity_sold': 4}, {'product_title': 'Heavyweight Oversized Tee', 'quantity_sold': 3}, {'product_title': 'Oversized Pullover Hoodie', 'quantity_sold': 15}, {'product_title': 'Denim Jacket', 'quantity_sold': 6}, {'product_title': 'Relaxed Fit Chinos', 'quantity_sold': 4}, {'product_title': 'Canvas Tote Bag', 'quantity_sold': 3}, {'product_title': 'Ankle Socks 3-Pack', 'quantity_sold': 4}, {'product_title': 'Wool Beanie', 'quantity_sold': 8}]}, {'month': '2024-02', 'product_list': [{'product_title': 'Classic Cotton Tee', 'quantity_sold': 8}, {'product_title': 'Slim Fit Crew Tee', 'quantity_sold': 7}, {'product_title': 'Heavyweight Oversized Tee', 'quantity_sold': 6}, {'product_title': 'Oversized Pullover Hoodie', 'quantity_sold': 20}, {'product_title': 'Denim Jacket', 'quantity_sold': 10}, {'product_title': 'Relaxed Fit Chinos', 'quantity_sold': 9}, {'product_title': 'Canvas Tote Bag', 'quantity_sold': 8}, {'product_title': 'Ankle Socks 3-Pack', 'quantity_sold': 5}, {'product_title': 'Wool Beanie', 'quantity_sold': 14}]}, {'month': '2024-03', 'product_list': [{'product_title': 'Classic Cotton Tee', 'quantity_sold': 20}, {'product_title': 'Slim Fit Crew Tee', 'quantity_sold': 15}, {'product_title': 'Heavyweight Oversized Tee', 'quantity_sold': 10}, {'product_title': 'Oversized Pullover Hoodie', 'quantity_sold': 18}, {'product_title': 'Denim Jacket', 'quantity_sold': 12}, {'product_title': 'Relaxed Fit Chinos', 'quantity_sold': 8}, {'product_title': 'Canvas Tote Bag', 'quantity_sold': 6}, {'product_title': 'Ankle Socks 3-Pack', 'quantity_sold': 5}, {'product_title': 'Wool Beanie', 'quantity_sold': 4}, {'product_title': 'Vintage Washed Tee', 'quantity_sold': 7}, {'product_title': 'Mini Sling Bag', 'quantity_sold': 4}, {'product_title': 'Unisex Thermal Long Sleeve Tee', 'quantity_sold': 5}]}, {'month': '2024-04', 'product_list': [{'product_title': 'Classic Cotton Tee', 'quantity_sold': 20}, {'product_title': 'Slim Fit Crew Tee', 'quantity_sold': 18}, {'product_title': 'Heavyweight Oversized Tee', 'quantity_sold': 12}, {'product_title': 'Oversized Pullover Hoodie', 'quantity_sold': 10}, {'product_title': 'Denim Jacket', 'quantity_sold': 15}, {'product_title': 'Relaxed Fit Chinos', 'quantity_sold': 10}, {'product_title': 'Canvas Tote Bag', 'quantity_sold': 8}, {'product_title': 'Ankle Socks 3-Pack', 'quantity_sold': 5}, {'product_title': 'Wool Beanie', 'quantity_sold': 4}, {'product_title': 'Vintage Washed Tee', 'quantity_sold': 6}, {'product_title': 'Mini Sling Bag', 'quantity_sold': 4}, {'product_title': 'Unisex Thermal Long Sleeve Tee', 'quantity_sold': 4}]}, {'month': '2024-05', 'product_list': [{'product_title': 'Classic Cotton Tee', 'quantity_sold': 20}, {'product_title': 'Slim Fit Crew Tee', 'quantity_sold': 18}, {'product_title': 'Heavyweight Oversized Tee', 'quantity_sold': 10}, {'product_title': 'Oversized Pullover Hoodie', 'quantity_sold': 8}, {'product_title': 'Denim Jacket', 'quantity_sold': 12}, {'product_title': 'Relaxed Fit Chinos', 'quantity_sold': 15}, {'product_title': 'Canvas Tote Bag', 'quantity_sold': 7}, {'product_title': 'Ankle Socks 3-Pack', 'quantity_sold': 5}, {'product_title': 'Wool Beanie', 'quantity_sold': 3}, {'product_title': 'Vintage Washed Tee', 'quantity_sold': 10}, {'product_title': 'Mini Sling Bag', 'quantity_sold': 6}, {'product_title': 'Unisex Thermal Long Sleeve Tee', 'quantity_sold': 4}, {'product_title': 'Graphic Print Tee', 'quantity_sold': 10}, {'product_title': 'Boxy Hoodie', 'quantity_sold': 6}, {'product_title': 'Wide Leg Utility Pants', 'quantity_sold': 4}, {'product_title': 'Minimalist Crewneck Sweatshirt', 'quantity_sold': 6}]}, {'month': '2024-06', 'product_list': [{'product_title': 'Classic Cotton Tee', 'quantity_sold': 30}, {'product_title': 'Slim Fit Crew Tee', 'quantity_sold': 25}, {'product_title': 'Heavyweight Oversized Tee', 'quantity_sold ...

# %% [markdown]
# ## Build orders, assign quantity to valid customer
#
#
# we just need: variant_id, quantity, customer

# %%
with open('data/all_months_prod_list.json', 'r') as f:
    all_months_prod_list = json.load(f)

# %%
import random
import datetime
import time

# %%
import numpy as np

# Assume all_months_prod_list is a list of dicts with "month" and "product_list" (with "variant_id" and "quantity_sold")
# Assume months is a list of month strings in the same order as all_months_prod_list

months_idx_to_inject = [11]

for month_idx, month in enumerate(months):

    if month_idx in months_idx_to_inject: #only do for months in months_idx_to_inject
        
        print("injecting for month: ", month)

        
        valid_cust = get_valid_customers_for_month(customer_df, month)
        month_prod_list = [x for x in all_months_prod_list if x["month"] == month][0]["product_list"]

        total_item_sold_in_month = sum([prod["quantity_sold"] for prod in month_prod_list])

        remainder_quantity = total_item_sold_in_month

        # 1. Get one timer segment from valid_cust
        one_timer_cust = valid_cust[valid_cust["segment"] == "one-timer"]
        if len(one_timer_cust) == 0:
            continue  # skip if no one-timer
        
        quantity_to_assign_one_timer = len(one_timer_cust)

        if(quantity_to_assign_one_timer > 0):

            one_timer_cust = one_timer_cust.copy()
            one_timer_cust["item_quantity"] = 1
            # display(one_timer_cust)


        remainder_quantity -= quantity_to_assign_one_timer


        # 2. Now get the remainder valid_cust, and remainder product to be sold
        assigned_one_timer_ids = set(one_timer_cust["id"])
        remainder_valid_cust = valid_cust[~valid_cust["id"].isin(assigned_one_timer_ids)]
        # display(remainder_valid_cust)
        
        # Get new customers from the remainder_valid_cust whose created_at date is in this month
        # Assume created_at is in format YYYY-MM-DD and month is in format YYYY-MM
        month_str = str(month)
        # Ensure 'created_at' is string type before using .str accessor
        new_cust = remainder_valid_cust[
            remainder_valid_cust["created_at"].astype(str).str.startswith(month_str)
        ]

        n_new_cust = len(new_cust)
        n_remainder_valid_cust = len(remainder_valid_cust)
        new_cust_percentage = n_new_cust / n_remainder_valid_cust if n_remainder_valid_cust > 0 else 0
        # print(f"Percentage of new customers to remainder valid customers in {month}: {new_cust_percentage:.2%}")
        # print("number of new customer",n_new_cust)
        # print("number of remainder item",remainder_quantity)

        # display(new_cust)

        quantity_to_assign_new_cust = n_new_cust

        if(quantity_to_assign_new_cust > 0):
            new_cust = new_cust.copy()
            new_cust["item_quantity"] = 1
        

        remainder_quantity -= quantity_to_assign_new_cust

        # print("remainder qty", remainder_quantity)

        # Get other valid customers from remainder_valid_cust that are not new
        other_valid_cust = remainder_valid_cust[~remainder_valid_cust["id"].isin(new_cust["id"])]

        if len(other_valid_cust) > 0:
            
            # Assign remainder_quantity items randomly to other_valid_cust, allowing some to get 0
            if remainder_quantity > 0:
                # Each customer can get 0 or more, sum equals remainder_quantity
                random_assignment = np.random.multinomial(remainder_quantity, [1/len(other_valid_cust)]*len(other_valid_cust))
                other_valid_cust = other_valid_cust.copy()
                other_valid_cust["item_quantity"] = random_assignment
            else:
                other_valid_cust = other_valid_cust.copy()
                other_valid_cust["item_quantity"] = 0
            
            # display(other_valid_cust)
            # Validate if the total quantity of other_valid_cust is the same as remainder_quantity
            # if len(other_valid_cust) > 0:
            #     total_assigned = other_valid_cust["item_quantity"].sum()
            #     if total_assigned != remainder_quantity:
            #         print(f"Warning: Total assigned quantity to other_valid_cust ({total_assigned}) does not match remainder_quantity ({remainder_quantity})")
            #     else:
            #         print("all good")

        else:
            # Assign remainder_quantity randomly to the new_cust["item_quantity"]
            if len(new_cust) > 0 and remainder_quantity > 0:
                # Each new_cust already has 1 item assigned; now distribute the remainder_quantity on top
                # Generate a random distribution of remainder_quantity into len(new_cust) bins (customers)
                # Each customer gets at least 0, sum equals remainder_quantity
                # Use multinomial for this
                random_assignment = np.random.multinomial(remainder_quantity, [1/len(new_cust)]*len(new_cust))
                new_cust = new_cust.copy()
                new_cust["item_quantity"] = 1 + random_assignment
            
            # Validate if the total quantity of new_cust is the same as remainder_quantity
            # if len(new_cust) > 0:
            #     total_new_cust_qty = new_cust["item_quantity"].sum()
            #     if total_new_cust_qty != quantity_to_assign_new_cust + (remainder_quantity if len(other_valid_cust) == 0 else 0):
            #         print(f"Warning: Total assigned quantity to new_cust ({total_new_cust_qty}) does not match expected ({quantity_to_assign_new_cust + (remainder_quantity if len(other_valid_cust) == 0 else 0)})")
            #     else:
            #         # print("all good")


        # Combine one_timer_cust, new_cust, and other_valid_cust into a single DataFrame
        combined_assigned_cust = pd.concat([one_timer_cust, new_cust, other_valid_cust], ignore_index=True)

        print("all_possible_cust: ", len(combined_assigned_cust))

        # assign variant id to each customer
        
        # Convert month_prod_list to a DataFrame
        month_prod_df = pd.DataFrame(month_prod_list)
        month_prod_df = month_prod_df.sort_values(by="quantity_sold", ascending=False).reset_index(drop=True)

        # display(month_prod_df)

        flat_variant_rows = []

        for idx, row in month_prod_df.iterrows():
            product_title = row["product_title"]
            quantity = int(row["quantity_sold"])

            # Get all variants for this product
            variants = product_df[product_df["title"] == product_title]["variant_id"].tolist()
            if not variants or quantity == 0:
                continue

            # Randomly select a variant for each unit sold
            chosen_variants = np.random.choice(variants, size=quantity, replace=True)
            for variant_id in chosen_variants:
                flat_variant_rows.append({"product_title": product_title, "variant_id": variant_id})

        flat_variant_id_df = pd.DataFrame(flat_variant_rows)
        flat_variant_id_df = flat_variant_id_df.sample(frac=1, random_state=42).reset_index(drop=True)
        # display(flat_variant_id_df)

        # Assign variant ids to each customer based on their item_quantity
        # flat_variant_id_df contains the shuffled list of variant_ids for this month

        # Calculate the total number of items to assign
        # total_items_to_assign = combined_assigned_cust["item_quantity"].sum()
        # # Get the variant_ids to assign (as a list)
        # variant_ids_to_assign = flat_variant_id_df["variant_id"].tolist()[:total_items_to_assign]
        variant_ids_to_assign = flat_variant_id_df["variant_id"].tolist()

        # Assign slices of variant_ids to each customer
        variants_id_col = []
        idx = 0
        for qty in combined_assigned_cust["item_quantity"]:
            qty = int(qty)
            variants_for_cust = variant_ids_to_assign[idx:idx+qty]
            variants_id_col.append(variants_for_cust)
            idx += qty

        combined_assigned_cust = combined_assigned_cust.copy()
        combined_assigned_cust["variants_id"] = variants_id_col

        # display(combined_assigned_cust)


        # inject to shopify graphQL

        # Helper to get a random datetime string in a given month (YYYY-MM)
        def random_datetime_in_month(month_str, before_date=None):
            # month_str: "2024-03"
            year, month = map(int, month_str.split('-'))
            if month == 12:
                next_month = datetime.datetime(year + 1, 1, 1)
            else:
                next_month = datetime.datetime(year, month + 1, 1)
            start = datetime.datetime(year, month, 1)
            end = next_month - datetime.timedelta(seconds=1)
            if before_date is not None:
                # before_date is a Timestamp or string
                if isinstance(before_date, str):
                    before_date = pd.to_datetime(before_date)
                if before_date < start:
                    # fallback to start
                    end = start
                elif before_date < end:
                    end = before_date - pd.Timedelta(seconds=1)
            # Pick a random datetime between start and end
            delta = end - start
            random_second = random.randint(0, int(delta.total_seconds()))
            dt = start + datetime.timedelta(seconds=random_second)
            return dt.strftime("%Y-%m-%dT%H:%M:%S-00:00")

        injecting_idx = 0

        this_month_valid_cust = 0

        # do_job = False

        for cust_idx, cust_row in combined_assigned_cust.iterrows():
            # print("injecting.....")
    
            customer_id = cust_row.get("id", None)

            # if str(customer_id) == "9059443278152":
            #     do_job = True
            # if not do_job:
            #     continue

            
            if not customer_id or not cust_row["variants_id"]:
                # print("skipping")
                continue  # skip if no customer or no variants
            
            this_month_valid_cust += 1

            print("injecting", customer_id)

            # Prepare line_items: each variant_id, quantity 1
            line_items = []
            for variant_id in cust_row["variants_id"]:
                line_items.append({
                    "variant_id": int(variant_id),
                    "quantity": 1
                })

            # Determine order date logic
            created_at = cust_row.get("created_at", None)
            churned_at = cust_row.get("churned_at", None)
            month_str = cust_row.get("order_month", None)
            # If not present, fallback to month variable
            if not month_str:
                month_str = month

            # If created_at is in this month, use that date
            use_date = None
            if pd.notnull(created_at) and str(created_at)[:7] == month_str:
                use_date = pd.to_datetime(created_at)
            elif pd.notnull(churned_at) and str(churned_at)[:7] == month_str:
                # churned this month: pick random date before churned_at
                use_date = random_datetime_in_month(month_str, before_date=churned_at)
            else:
                # random date in this month
                use_date = random_datetime_in_month(month_str)

            if isinstance(use_date, pd.Timestamp):
                date_str = use_date.strftime("%Y-%m-%dT%H:%M:%S-00:00")
            else:
                date_str = use_date  # already string

            order_data = {
                "order": {
                    "line_items": line_items,
                    # "created_at": date_str,
                    "processed_at": date_str,
                    # "closed_at": date_str,
                    "financial_status": "paid",
                    "fulfillment_status": "fulfilled",
                    "customer": {
                        "id": int(customer_id)
                    },
                }
            }

            order = shopify.Order()
            order.attributes = order_data["order"]
            try:
                response = order.save()
            except Exception as e:
                print(f"Failed to create order for customer {customer_id}: {e}")

            # sleep for rate limiting (4 orders per minute, from shopify)
            injecting_idx += 1
            if injecting_idx == 4:
                injecting_idx = 0
                time.sleep(61)

        print("ordering cust: ", this_month_valid_cust)


    # break
# Out:
# injecting for month:  2024-12
# all_possible_cust:  213
# injecting 9059452518728
# injecting 9059452813640
# injecting 9059452420424
# injecting 9059452485960
# injecting 9059452584264
# injecting 9059452617032
# injecting 9059452649800
# injecting 9059452682568
# injecting 9059452715336
# injecting 9059452780872
# injecting 9059452879176
# injecting 9059452911944
# injecting 9059452944712
# injecting 9059452977480
# injecting 9059453010248
# injecting 9059439771976
# injecting 9059439804744
# injecting 9059439968584
# injecting 9059440034120
# injecting 9059440099656
# injecting 9059440165192
# injecting 9059440197960
# injecting 9059440230728
# injecting 9059440361800
# injecting 9059440722248
# injecting 9059440787784
# injecting 9059440820552
# injecting 9059441148232
# injecting 9059441181000
# injecting 9059441246536
# injecting 9059441279304
# injecting 9059441377608
# injecting 9059441410376
# injecting 9059441606984
# injecting 9059441639752
# injecting 9059441705288
# injecting 9059441836360
# injecting 9059442032968
# injecting 9059442098504
# injecting 9059442131272
# injecting 9059442164040
# injecting 9059442229576
# injecting 9059442327880
# injecting 9059442360648
# injecting 9059442557256
# injecting 9059442622792
# injecting 9059442655560
# injecting 9059442721096
# injecting 9059442819400
# injecting 9059442884936
# injecting 9059442917704
# injecting 9059442950472
# injecting 9059443016008
# injecting 9059443081544
# injecting 9059443114312
# injecting 9059443147080
# injecting 9059443278152
# injecting 9059443409224
# injecting 9059443507528
# injecting 9059443704136
# injecting 9059443802440
# injecting 9059443867976
# injecting 9059444064584
# injecting 9059444162888
# injecting 9059444195656
# injecting 9059444293960
# injecting 9059444392264
# injecting 9059444457800
# injecting 9059444523336
# injecting 9059444556104
# injecting 9059444588872
# injecting 9059444654408
# injecting 9059444719944
# injecting 9059444785480
# injecting 9059444851016
# injecting 9059444982088
# injecting 9059445047624
# injecting 9059445277000
# injecting 9059445342536
# injecting 9059445408072
# injecting 9059445440840
# injecting 9059445539144
# injecting 9059445604680
# injecting 9059445670216
# injecting 9059445735752
# injecting 9059445768520
# injecting 9059445834056
# injecting 9059445866824
# injecting 9059445932360
# injecting 9059445965128
# injecting 9059446063432
# injecting 9059446096200
# injecting 9059446128968
# injecting 9059446194504
# injecting 9059446260040
# injecting 9059446292808
# injecting 9059446325576
# injecting 9059446489416
# injecting 9059446587720
# injecting 9059446620488
# injecting 9059446686024
# injecting 9059446784328
# injecting 9059446817096
# injecting 9059446882632
# injecting 9059446915400
# injecting 9059446980936
# injecting 9059447046472
# injecting 9059447079240
# injecting 9059447112008
# injecting 9059447144776
# injecting 9059447243080
# injecting 9059447341384
# injecting 9059447406920
# injecting 9059447537992
# injecting 9059447603528
# injecting 9059447636296
# injecting 9059447669064
# injecting 9059447701832
# injecting 9059447832904
# injecting 9059447963976
# injecting 9059448029512
# injecting 9059448127816
# injecting 9059448258888
# injecting 9059448291656
# injecting 9059448389960
# injecting 9059448488264
# injecting 9059448619336
# injecting 9059448652104
# injecting 9059448750408
# injecting 9059448848712
# injecting 9059449045320
# injecting 9059449078088
# injecting 9059449176392
# injecting 9059449209160
# injecting 9059449373000
# injecting 9059449405768
# injecting 9059449635144
# injecting 9059449667912
# injecting 9059449700680
# injecting 9059449766216
# injecting 9059449798984
# injecting 9059449831752
# injecting 9059449864520
# injecting 9059449897288
# injecting 9059449995592
# injecting 9059450061128
# injecting 9059450126664
# injecting 9059450192200
# injecting 9059450257736
# injecting 9059450323272
# injecting 9059450356040
# injecting 9059450454344
# injecting 9059450487112
# injecting 9059450650952
# injecting 9059450716488
# injecting 9059450814792
# injecting 9059450847560
# injecting 9059450913096
# injecting 9059450945864
# injecting 9059451011400
# injecting 9059451044168
# injecting 9059451109704
# injecting 9059451142472
# injecting 9059451175240
# injecting 9059451273544
# injecting 9059451306312
# injecting 9059451339080
# injecting 9059451371848
# injecting 9059451437384
# injecting 9059451470152
# injecting 9059451568456
# injecting 9059451633992
# injecting 9059451699528
# injecting 9059451797832
# injecting 9059451830600
# injecting 9059451928904
# injecting 9059451961672
# injecting 9059451994440
# injecting 9059452059976
# injecting 9059452125512
# injecting 9059452158280
# injecting 9059452256584
# injecting 9059452354888
# injecting 9059452387656
# ordering cust:  184
